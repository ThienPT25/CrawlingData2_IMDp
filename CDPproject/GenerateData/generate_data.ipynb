# %%
import random, json

def calculate_score():
    return random.randint(0,10), random.randint(10,20),random.randint(20,30),random.randint(30,40),random.randint(40,50)

title = ['mu', 'ao', 'quan', 'giay', 'dien thoai', 'tai phone', 'tu lanh', 'ao len', 'quan dui', 'giay dap']

json_obj_list = []
for i in range(100):
    tp, fp, tn, fn, ar = calculate_score()
    json_obj_list.append({"channel": "web", "context": {"app": {"build": "1.0.0", 
                                                                "name": "RudderLabs JavaScript SDK", 
                                                                "namespace": "com.rudderlabs.javascript", 
                                                                "version": "1.1.18"}, 
                                                        "traits": {}, 
                                                        "library": {"name": "RudderLabs JavaScript SDK", 
                                                                    "version": "1.1.18"}, 
                                                        "userAgent": "Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_6; zh-cn) AppleWebKit/533.20.25 (KHTML, like Gecko) Version/5.0.4 Safari/533.20.27", 
                                                        "locale": "en-US", 
                                                        "os": {"name": "", 
                                                               "version": ""}, 
                                                        "screen": {"density": tp, 
                                                                   "width": fp, 
                                                                   "height": tn, 
                                                                   "innerWidth": fn, 
                                                                   "innerHeight": ar}, 
                                                        "campaign": {}, 
                                                        "page": {"path": "/Quan_short_421.html", 
                                                                 "referrer": "http://shop.analyticsguru.link/", 
                                                                 "referring_domain": "vnexress.net", 
                                                                 "search": "", 
                                                                 "title": title[tp], 
                                                                 "url": "http://shop.analyticsguru.link/mult.html", 
                                                                 "tab_url": "http://shop.analyticsguru.link//" + title[tp] + ".html", 
                                                                 "initial_referrer": "$direct", "initial_referring_domain": ""}}, 
                          "type": "page", 
                          "messageId": "e424216b-b396-4ebe-98be-00ec362bf894", 
                          "originalTimestamp": "2021-08-06T04:23:43.476Z", 
                          "anonymousId": "611f2fe4-010f-4616-823c-e7f59e85af65", 
                          "userId": "", 
                          "properties": {"path": title[tp] + ".html", 
                                         "referrer": "http://shop.analyticsguru.link/", 
                                         "referring_domain": "tuoitre.vn", 
                                         "search": "", 
                                         "title": title[tp], 
                                         "url": "http://shop.analyticsguru.link/" + title[tp] + ".html", 
                                         "tab_url": "http://shop.analyticsguru.link//" + title[tp] + ".html", 
                                         "initial_referrer": "$direct", 
                                         "initial_referring_domain": ""}, 
                          "integrations": {"All": "true"}, 
                          "sentAt": "2021-08-06T04:37:08.537877", 
                          "tenant_id": "Customer187"})


json_dump = json.dumps(json_obj_list, indent="\t")
print(json_dump)
# Out:
# [
# 	{
# 		"channel": "web",
# 		"context": {
# 			"app": {
# 				"build": "1.0.0",
# 				"name": "RudderLabs JavaScript SDK",
# 				"namespace": "com.rudderlabs.javascript",
# 				"version": "1.1.18"
# 			},
# 			"traits": {},
# 			"library": {
# 				"name": "RudderLabs JavaScript SDK",
# 				"version": "1.1.18"
# 			},
# 			"userAgent": "Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_6; zh-cn) AppleWebKit/533.20.25 (KHTML, like Gecko) Version/5.0.4 Safari/533.20.27",
# 			"locale": "en-US",
# 			"os": {
# 				"name": "",
# 				"version": ""
# 			},
# 			"screen": {
# 				"density": 8,
# 				"width": 13,
# 				"height": 26,
# 				"innerWidth": 39,
# 				"innerHeight": 49
# 			},
# 			"campaign": {},
# 			"page": {
# 				"path": "/Quan_short_421.html",
# 				"referrer": "http://shop.analyticsguru.link/",
# 				"referring_domain": "vnexress.net",
# 				"search": "",
# 				"title": "quan dui",
# 				"url": "http://shop.analyticsguru.link/mult.html",
# 				"tab_url": "http://shop.analyticsguru.link//quan dui.html",
# 				"initial_referrer": "$direct",
# 				"initial_referring_domain": ""
# 			}
# 		},
# 		"type": "page",
# 		"messageId": "e424216b-b396-4ebe-98be-00ec362bf894",
# 		"originalTimestamp": "2021-08-06T04:23:43.476Z",
# 		"anonymousId": "611f2fe4-010f-4616-823c-e7f59e85af65",
# 		"userId": "",
# 		"properties": {
# 			"path": "quan dui.html",
# 			"referrer": "http://shop.analyticsguru.link/",
# 			"referring_domain": "tuoitre.vn",
# 			"search": "",
# 			"title": "quan dui",
# 			"url": "http://shop.analyticsguru.link/quan dui.html",
# 			"tab_url": "http://shop.analyticsguru.link//quan dui.html",
# 			"initial_referrer": "$direct",
# 			"initial_referring_domain": ""
# 		},
# 		"integrations": {
# 			"All": "true"
# 		},
# 		"sentAt": "2021-08-06T04:37:08.537877",
# 		"tenant_id": "Customer187"
# 	}
# ]

# %%
#open text file
text_file = open("data.json", "w")
 
#write string to file
n = text_file.write(json_dump)
 
#close file
text_file.close()
